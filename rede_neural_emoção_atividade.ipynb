# %% [markdown]
# #Rede neural para detecção de emoção: feliz ou triste

# %%
import cv2
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile
import numpy as np
from google.colab.patches import cv2_imshow
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
caminho = '/content/drive/MyDrive/estudo de visao computacional/Datasets/fer2013_2_classes.zip'
zipado = zipfile.ZipFile(caminho, mode='r')
zipado.extractall('./')
zipado.close()

# %%
tf.keras.preprocessing.image.load_img('/content/fer2013_2_classes/train/Angry/101.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=48x48>

# %%
tf.keras.preprocessing.image.load_img('/content/fer2013_2_classes/train/Happy/1011.jpg')
# Out:
# <PIL.Image.Image image mode=RGB size=48x48>

# %%
gerador_treino = ImageDataGenerator(rescale = 1./255,
                                    rotation_range=7,
                                    horizontal_flip=True,
                                    zoom_range=0.2)
base_treino= gerador_treino.flow_from_directory('/content/fer2013_2_classes/train',
                                                target_size=(48,48),
                                                class_mode='categorical',
                                                batch_size = 50,
                                                shuffle = True)
# Out:
# Found 11210 images belonging to 2 classes.

# %%
gerador_teste = ImageDataGenerator(rescale=1./255)
base_teste = gerador_teste.flow_from_directory('/content/fer2013_2_classes/validation',
                                                target_size=(48,48),
                                                class_mode='categorical',
                                                batch_size = 1,
                                                shuffle = False)
# Out:
# Found 1370 images belonging to 2 classes.

# %%
sns.countplot(x=base_treino.classes)
# Out:
# <Axes: ylabel='count'>

# %%
base_treino.class_indices
# Out:
# {'Angry': 0, 'Happy': 1}

# %%
# Based on: https://github.com/rajeevratan84/DeepLearningCV/blob/master/18.2%20Building%20an%20Emotion%20Detector%20with%20LittleVGG.ipynb
#padding: o tipo 'VALID' ignora os pixeis das bordas na hora da aplicação de kernel, já o 'SAME', mantem todos os pixeis, mantendo o tamanho da imagem
numero_detectores = 32
#numero de filtros da rede neural
numero_classes = 2
largura, altura = 48, 48
epocas = 150

rede = Sequential()
rede.add(Conv2D(filters = numero_detectores, kernel_size=(3,3), activation='relu', padding='same', input_shape=(largura,altura,3)))
rede.add(BatchNormalization())
rede.add(Conv2D(filters = numero_detectores, kernel_size=(3,3), activation='relu', padding='same'))
rede.add(BatchNormalization())
rede.add(MaxPooling2D(pool_size=(2,2)))
rede.add(Dropout(0.2))

rede.add(Conv2D(filters = 2*numero_detectores, kernel_size=(3,3), activation='relu', padding='same'))
rede.add(BatchNormalization())
rede.add(Conv2D(filters = 2*numero_detectores, kernel_size=(3,3), activation='relu', padding='same'))
rede.add(BatchNormalization())
rede.add(MaxPooling2D(pool_size=(2,2)))
rede.add(Dropout(0.2))

rede.add(Conv2D(filters = 4*numero_detectores, kernel_size=(3,3), activation='relu', padding='same'))
rede.add(BatchNormalization())
rede.add(Conv2D(filters = 4*numero_detectores, kernel_size=(3,3), activation='relu', padding='same'))
rede.add(BatchNormalization())
rede.add(MaxPooling2D(pool_size=(2,2)))
rede.add(Dropout(0.2))

rede.add(Conv2D(filters = 8*numero_detectores, kernel_size=(3,3), activation='relu', padding='same'))
rede.add(BatchNormalization())
rede.add(Conv2D(filters = 8*numero_detectores, kernel_size=(3,3), activation='relu', padding='same'))
rede.add(BatchNormalization())
rede.add(MaxPooling2D(pool_size=(2,2)))
rede.add(Dropout(0.2))

rede.add(Flatten())

rede.add(Dense(units= 2*numero_detectores, activation='relu'))
rede.add(BatchNormalization())
rede.add(Dropout(0.2))

rede.add(Dense(units= 2*numero_detectores, activation='relu'))
rede.add(BatchNormalization())
rede.add(Dropout(0.2))

rede.add(Dense(units=2, activation='softmax'))

# %%
rede.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_32 (Conv2D)          (None, 48, 48, 32)        896
#
#  batch_normalization_40 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  conv2d_33 (Conv2D)          (None, 48, 48, 32)        9248
#
#  batch_normalization_41 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  max_pooling2d_16 (MaxPoolin  (None, 24, 24, 32)       0
#  g2D)
#
#  dropout_24 (Dropout)        (None, 24, 24, 32)        0
#
#  conv2d_34 (Conv2D)          (None, 24, 24, 64)        18496
#
#  batch_normalization_42 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  conv2d_35 (Conv2D)          (None, 24, 24, 64)        36928
#
#  batch_normalization_43 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  max_pooling2d_17 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  dropout_25 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_36 (Conv2D)          (None, 12, 12, 128)       73856
#
#  batch_normalization_44 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_37 (Conv2D)          (None, 12, 12, 128)       147584
#
#  batch_normalization_45 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  max_pooling2d_18 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_26 (Dropout)        (None, 6, 6, 128)         0
#
#  conv2d_38 (Conv2D)          (None, 6, 6, 256)         295168
#
#  batch_normalization_46 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_39 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batch_normalization_47 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  max_pooling2d_19 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  dropout_27 (Dropout)        (None, 3, 3, 256)         0
#
#  flatten_4 (Flatten)         (None, 2304)              0
#
#  dense_12 (Dense)            (None, 64)                147520
#
#  batch_normalization_48 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_28 (Dropout)        (None, 64)                0
#
#  dense_13 (Dense)            (None, 64)                4160
#
#  batch_normalization_49 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_29 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 1,328,418
# Trainable params: 1,326,242
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
rede.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
historico = rede.fit(base_treino, epochs = epocas)
# Out:
# Epoch 1/150
# 225/225 [==============================] - 37s 75ms/step - loss: 0.7720 - accuracy: 0.5954
# Epoch 2/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.6025 - accuracy: 0.6881
# Epoch 3/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.4615 - accuracy: 0.7868
# Epoch 4/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.3808 - accuracy: 0.8289
# Epoch 5/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.3407 - accuracy: 0.8500
# Epoch 6/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.3230 - accuracy: 0.8630
# Epoch 7/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.3018 - accuracy: 0.8700
# Epoch 8/150
# 225/225 [==============================] - 18s 79ms/step - loss: 0.2924 - accuracy: 0.8776
# Epoch 9/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.2747 - accuracy: 0.8839
# Epoch 10/150
# 225/225 [==============================] - 17s 77ms/step - loss: 0.2680 - accuracy: 0.8873
# Epoch 11/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.2542 - accuracy: 0.8916
# Epoch 12/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.2467 - accuracy: 0.8983
# Epoch 13/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.2391 - accuracy: 0.8996
# Epoch 14/150
# 225/225 [==============================] - 18s 79ms/step - loss: 0.2288 - accuracy: 0.9068
# Epoch 15/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.2296 - accuracy: 0.9059
# Epoch 16/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.2260 - accuracy: 0.9073
# Epoch 17/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.2185 - accuracy: 0.9098
# Epoch 18/150
# 225/225 [==============================] - 18s 80ms/step - loss: 0.2125 - accuracy: 0.9164
# Epoch 19/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.2104 - accuracy: 0.9150
# Epoch 20/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1986 - accuracy: 0.9237
# Epoch 21/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.2047 - accuracy: 0.9186
# Epoch 22/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1971 - accuracy: 0.9192
# Epoch 23/150
# 225/225 [==============================] - 17s 77ms/step - loss: 0.1974 - accuracy: 0.9219
# Epoch 24/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1850 - accuracy: 0.9277
# Epoch 25/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.1850 - accuracy: 0.9250
# Epoch 26/150
# 225/225 [==============================] - 18s 79ms/step - loss: 0.1805 - accuracy: 0.9271
# Epoch 27/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1660 - accuracy: 0.9344
# Epoch 28/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1689 - accuracy: 0.9343
# Epoch 29/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.1757 - accuracy: 0.9309
# Epoch 30/150
# 225/225 [==============================] - 17s 78ms/step - loss: 0.1621 - accuracy: 0.9376
# Epoch 31/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1624 - accuracy: 0.9349
# Epoch 32/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1605 - accuracy: 0.9383
# Epoch 33/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.1561 - accuracy: 0.9406
# Epoch 34/150
# 225/225 [==============================] - 18s 81ms/step - loss: 0.1446 - accuracy: 0.9480
# Epoch 35/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1456 - accuracy: 0.9440
# Epoch 36/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1443 - accuracy: 0.9469
# Epoch 37/150
# 225/225 [==============================] - 18s 78ms/step - loss: 0.1484 - accuracy: 0.9439
# Epoch 38/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1418 - accuracy: 0.9464
# Epoch 39/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1399 - accuracy: 0.9461
# Epoch 40/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.1324 - accuracy: 0.9498
# Epoch 41/150
# 225/225 [==============================] - 18s 81ms/step - loss: 0.1307 - accuracy: 0.9499
# Epoch 42/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1297 - accuracy: 0.9515
# Epoch 43/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.1195 - accuracy: 0.9544
# Epoch 44/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1148 - accuracy: 0.9562
# Epoch 45/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1137 - accuracy: 0.9562
# Epoch 46/150
# 225/225 [==============================] - 18s 80ms/step - loss: 0.1162 - accuracy: 0.9577
# Epoch 47/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.1144 - accuracy: 0.9559
# Epoch 48/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1070 - accuracy: 0.9592
# Epoch 49/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1049 - accuracy: 0.9624
# Epoch 50/150
# 225/225 [==============================] - 18s 79ms/step - loss: 0.1050 - accuracy: 0.9616
# Epoch 51/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.1084 - accuracy: 0.9589
# Epoch 52/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.1000 - accuracy: 0.9623
# Epoch 53/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0978 - accuracy: 0.9630
# Epoch 54/150
# 225/225 [==============================] - 18s 82ms/step - loss: 0.0982 - accuracy: 0.9645
# Epoch 55/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0872 - accuracy: 0.9676
# Epoch 56/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0899 - accuracy: 0.9677
# Epoch 57/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0880 - accuracy: 0.9694
# Epoch 58/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0857 - accuracy: 0.9703
# Epoch 59/150
# 225/225 [==============================] - 18s 79ms/step - loss: 0.0840 - accuracy: 0.9665
# Epoch 60/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0837 - accuracy: 0.9690
# Epoch 61/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0790 - accuracy: 0.9705
# Epoch 62/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0859 - accuracy: 0.9682
# Epoch 63/150
# 225/225 [==============================] - 18s 79ms/step - loss: 0.0876 - accuracy: 0.9673
# Epoch 64/150
# 225/225 [==============================] - 17s 77ms/step - loss: 0.0795 - accuracy: 0.9702
# Epoch 65/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0776 - accuracy: 0.9721
# Epoch 66/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.0787 - accuracy: 0.9700
# Epoch 67/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0787 - accuracy: 0.9716
# Epoch 68/150
# 225/225 [==============================] - 18s 79ms/step - loss: 0.0768 - accuracy: 0.9712
# Epoch 69/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0700 - accuracy: 0.9740
# Epoch 70/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.0707 - accuracy: 0.9723
# Epoch 71/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.0696 - accuracy: 0.9745
# Epoch 72/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0689 - accuracy: 0.9741
# Epoch 73/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0573 - accuracy: 0.9790
# Epoch 74/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0643 - accuracy: 0.9786
# Epoch 75/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0624 - accuracy: 0.9780
# Epoch 76/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0710 - accuracy: 0.9754
# Epoch 77/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0655 - accuracy: 0.9764
# Epoch 78/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0624 - accuracy: 0.9766
# Epoch 79/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0642 - accuracy: 0.9760
# Epoch 80/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0546 - accuracy: 0.9789
# Epoch 81/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0627 - accuracy: 0.9774
# Epoch 82/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0540 - accuracy: 0.9812
# Epoch 83/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0629 - accuracy: 0.9756
# Epoch 84/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0610 - accuracy: 0.9777
# Epoch 85/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0496 - accuracy: 0.9814
# Epoch 86/150
# 225/225 [==============================] - 18s 80ms/step - loss: 0.0599 - accuracy: 0.9774
# Epoch 87/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0562 - accuracy: 0.9806
# Epoch 88/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0551 - accuracy: 0.9802
# Epoch 89/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0559 - accuracy: 0.9781
# Epoch 90/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0599 - accuracy: 0.9789
# Epoch 91/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0578 - accuracy: 0.9792
# Epoch 92/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0526 - accuracy: 0.9806
# Epoch 93/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0532 - accuracy: 0.9804
# Epoch 94/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0507 - accuracy: 0.9807
# Epoch 95/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0609 - accuracy: 0.9773
# Epoch 96/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0488 - accuracy: 0.9826
# Epoch 97/150
# 225/225 [==============================] - 18s 80ms/step - loss: 0.0463 - accuracy: 0.9821
# Epoch 98/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0550 - accuracy: 0.9810
# Epoch 99/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.0493 - accuracy: 0.9819
# Epoch 100/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0497 - accuracy: 0.9814
# Epoch 101/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0446 - accuracy: 0.9847
# Epoch 102/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0455 - accuracy: 0.9846
# Epoch 103/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0485 - accuracy: 0.9817
# Epoch 104/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0467 - accuracy: 0.9818
# Epoch 105/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0456 - accuracy: 0.9823
# Epoch 106/150
# 225/225 [==============================] - 17s 77ms/step - loss: 0.0423 - accuracy: 0.9840
# Epoch 107/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0442 - accuracy: 0.9847
# Epoch 108/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0449 - accuracy: 0.9848
# Epoch 109/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0441 - accuracy: 0.9828
# Epoch 110/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0486 - accuracy: 0.9828
# Epoch 111/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0457 - accuracy: 0.9824
# Epoch 112/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.0470 - accuracy: 0.9846
# Epoch 113/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0410 - accuracy: 0.9855
# Epoch 114/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0417 - accuracy: 0.9844
# Epoch 115/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0380 - accuracy: 0.9867
# Epoch 116/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0443 - accuracy: 0.9844
# Epoch 117/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0432 - accuracy: 0.9847
# Epoch 118/150
# 225/225 [==============================] - 17s 77ms/step - loss: 0.0431 - accuracy: 0.9837
# Epoch 119/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0331 - accuracy: 0.9885
# Epoch 120/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0361 - accuracy: 0.9863
# Epoch 121/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0526 - accuracy: 0.9830
# Epoch 122/150
# 225/225 [==============================] - 17s 77ms/step - loss: 0.0492 - accuracy: 0.9829
# Epoch 123/150
# 225/225 [==============================] - 16s 71ms/step - loss: 0.0395 - accuracy: 0.9863
# Epoch 124/150
# 225/225 [==============================] - 16s 71ms/step - loss: 0.0383 - accuracy: 0.9858
# Epoch 125/150
# 225/225 [==============================] - 16s 71ms/step - loss: 0.0320 - accuracy: 0.9870
# Epoch 126/150
# 225/225 [==============================] - 16s 71ms/step - loss: 0.0369 - accuracy: 0.9871
# Epoch 127/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0363 - accuracy: 0.9868
# Epoch 128/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0344 - accuracy: 0.9871
# Epoch 129/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.0331 - accuracy: 0.9886
# Epoch 130/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0361 - accuracy: 0.9868
# Epoch 131/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0372 - accuracy: 0.9856
# Epoch 132/150
# 225/225 [==============================] - 18s 78ms/step - loss: 0.0410 - accuracy: 0.9861
# Epoch 133/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0328 - accuracy: 0.9875
# Epoch 134/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0386 - accuracy: 0.9862
# Epoch 135/150
# 225/225 [==============================] - 16s 71ms/step - loss: 0.0390 - accuracy: 0.9848
# Epoch 136/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0355 - accuracy: 0.9871
# Epoch 137/150
# 225/225 [==============================] - 17s 76ms/step - loss: 0.0346 - accuracy: 0.9884
# Epoch 138/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0326 - accuracy: 0.9888
# Epoch 139/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0355 - accuracy: 0.9881
# Epoch 140/150
# 225/225 [==============================] - 16s 70ms/step - loss: 0.0288 - accuracy: 0.9895
# Epoch 141/150
# 225/225 [==============================] - 17s 73ms/step - loss: 0.0313 - accuracy: 0.9889
# Epoch 142/150
# 225/225 [==============================] - 16s 73ms/step - loss: 0.0287 - accuracy: 0.9888
# Epoch 143/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0364 - accuracy: 0.9881
# Epoch 144/150
# 225/225 [==============================] - 16s 71ms/step - loss: 0.0308 - accuracy: 0.9887
# Epoch 145/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0303 - accuracy: 0.9903
# Epoch 146/150
# 225/225 [==============================] - 17s 74ms/step - loss: 0.0352 - accuracy: 0.9871
# Epoch 147/150
# 225/225 [==============================] - 16s 72ms/step - loss: 0.0305 - accuracy: 0.9899
# Epoch 148/150
# 225/225 [==============================] - 16s 71ms/step - loss: 0.0298 - accuracy: 0.9886
# Epoch 149/150
# 225/225 [==============================] - 16s 70ms/step - loss: 0.0387 - accuracy: 0.9855
# Epoch 150/150
# 225/225 [==============================] - 17s 75ms/step - loss: 0.0328 - accuracy: 0.9875

# %%
plt.plot(historico.history['loss'])

# %%
plt.plot(historico.history['accuracy'])

# %%
arquitetura = rede.to_json()
with open('/content/drive/MyDrive/redes neurais/arquitetura_F_T.json', 'w') as arquivo:
  arquivo.write(arquitetura)

# %%
from keras.models import save_model
rede_salve = save_model(rede,'/content/drive/MyDrive/redes neurais/pesos_F_T.hdf5')

# %%
with open('/content/drive/MyDrive/redes neurais/arquitetura_F_T.json', 'r') as arquivo:
  arquitetura = arquivo.read()

# %%
rede = tf.keras.models.model_from_json(arquitetura)
rede.load_weights('/content/drive/MyDrive/redes neurais/pesos_F_T.hdf5')
rede.compile(optimizer='Adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %%
rede.evaluate(base_teste)
# Out:
# 1370/1370 [==============================] - 7s 5ms/step - loss: 0.2323 - accuracy: 0.9372
# [0.23226231336593628, 0.9372262954711914]

# %%
previsoes = rede.predict(base_teste)
previsoes = np.argmax(previsoes, axis = 1)
previsoes
# Out:
# 1370/1370 [==============================] - 5s 3ms/step
# array([0, 0, 0, ..., 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(base_teste.classes, previsoes)
# Out:
# 0.9372262773722628

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(base_teste.classes, previsoes)
sns.heatmap(cm , annot=True)
# Out:
# <Axes: >
