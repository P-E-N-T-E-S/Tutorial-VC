# %% [markdown]
# # Usando OpenCV

# %% [markdown]
# ## Carregando a base de dados
# - base de Yale: http://vision.ucsd.edu/content/yale-face-database

# %%
from PIL import Image
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import drive
import os
import zipfile
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
caminho = '/content/drive/MyDrive/estudo de visao computacional/Datasets/yalefaces.zip'
arquivo = zipfile.ZipFile(file=caminho, mode='r')
arquivo.extractall('./')
arquivo.close()

# %% [markdown]
# ## Pré-processamento das imagens

# %%
#trocar a extensão das imagens para conseguir treinar
caminho = '/content/yalefaces/train'
print(os.listdir(caminho))
# Out:
# ['subject03.sleepy.gif', 'subject14.happy.gif', 'subject06.glasses.gif', 'subject02.wink.gif', 'subject01.sleepy.gif', 'subject05.happy.gif', 'subject13.leftlight.gif', 'subject07.rightlight.gif', 'subject03.sad.gif', 'subject02.sleepy.gif', 'subject03.rightlight.gif', 'subject04.rightlight.gif', 'subject13.happy.gif', 'subject08.leftlight.gif', 'subject10.leftlight.gif', 'subject08.sleepy.gif', 'subject13.glasses.gif', 'subject14.rightlight.gif', 'subject14.centerlight.gif', 'subject08.surprised.gif', 'subject07.surprised.gif', 'subject14.glasses.gif', 'subject12.sad.gif', 'subject06.sleepy.gif', 'subject01.rightlight.gif', 'subject01.surprised.gif', 'subject09.wink.gif', 'subject10.noglasses.gif', 'subject10.surprised.gif', 'subject03.happy.gif', 'subject08.noglasses.gif', 'subject01.glasses.gif', 'subject09.centerlight.gif', 'subject06.noglasses.gif', 'subject06.surprised.gif', 'subject05.wink.gif', 'subject04.normal.gif', 'subject06.centerlight.gif', 'subject08.centerlight.gif', 'subject09.glasses.gif', 'subject08.wink.gif', 'subject03.surprised.gif', 'subject10.glasses.gif', 'subject02.glasses.gif', 'subject02.sad.gif', 'subject09.leftlight.gif', 'subject11.wink.gif', 'subject15.surprised.gif', 'subject03.wink.gif', 'subject05.normal.gif', 'subject15.sleepy.gif', 'subject04.noglasses.gif', 'subject01.noglasses.gif', 'subject14.leftlight.gif', 'subject07.glasses.gif', 'subject07.sad.gif', 'subject11.sleepy.gif', 'subject05.centerlight.gif', 'subject12.leftlight.gif', 'subject13.surprised.gif', 'subject07.centerlight.gif', 'subject02.surprised.gif', 'subject13.normal.gif', 'subject04.happy.gif', 'subject10.wink.gif', 'subject12.sleepy.gif', 'subject04.centerlight.gif', 'subject13.centerlight.gif', 'subject09.happy.gif', 'subject15.centerlight.gif', 'subject15.glasses.gif', 'subject14.sleepy.gif', 'subject08.sad.gif', 'subject10.sleepy.gif', 'subject11.leftlight.gif', 'subject15.happy.gif', 'subject05.leftlight.gif', 'subject05.glasses.gif', 'subject11.sad.gif', 'subject11.rightlight.gif', 'subject10.normal.gif', 'subject09.normal.gif', 'subject05.sad.gif', 'subject04.sad.gif', 'subject12.happy.gif', 'subject06.sad.gif', 'subject02.happy.gif', 'subject08.glasses.gif', 'subject09.noglasses.gif', 'subject06.normal.gif', 'subject10.rightlight.gif', 'subject04.wink.gif', 'subject15.leftlight.gif', 'subject06.rightlight.gif', 'subject11.surprised.gif', 'subject07.wink.gif', 'subject11.centerlight.gif', 'subject12.centerlight.gif', 'subject07.normal.gif', 'subject14.wink.gif', 'subject12.wink.gif', 'subject04.glasses.gif', 'subject01.leftlight.gif', 'subject01.sad.gif', 'subject11.normal.gif', 'subject12.glasses.gif', 'subject02.rightlight.gif', 'subject11.noglasses.gif', 'subject15.noglasses.gif', 'subject10.happy.gif', 'subject13.rightlight.gif', 'subject02.normal.gif', 'subject07.sleepy.gif', 'subject03.normal.gif', 'subject13.wink.gif', 'subject03.noglasses.gif', 'subject09.sleepy.gif', 'subject06.wink.gif', 'subject12.surprised.gif', 'subject15.normal.gif', 'subject13.noglasses.gif', 'subject12.noglasses.gif', 'subject05.noglasses.gif', 'subject14.surprised.gif', 'subject08.happy.gif', 'subject01.normal.gif', 'subject04.sleepy.gif', 'subject03.centerlight.gif', 'subject14.noglasses.gif', 'subject09.surprised.gif', 'subject05.rightlight.gif', 'subject01.wink.gif', 'subject02.noglasses.gif', 'subject15.wink.gif', 'subject07.noglasses.gif']

# %%
def pegar_dados_imagem(caminho):
  caminhos = [os.path.join(caminho, f) for f in os.listdir(caminho)]
  faces = [] #pixeis da imagem
  ids = [] #numero das pessoas
  for foto in caminhos:
    imagem = Image.open(foto).convert('L') #deixando no formato da biblioteca PIL, e e escala de cinza
    imagem_np = np.array(imagem, 'uint8')
    id = int(os.path.split(foto)[1].split('.')[0].replace('subject', '')) #pegando o numero da pessoa
    faces.append(imagem_np)
    ids.append(id)
  return np.array(ids), faces

# %%
ids, faces = pegar_dados_imagem(caminho)

# %%
ids
# Out:
# array([ 3, 14,  6,  2,  1,  5, 13,  7,  3,  2,  3,  4, 13,  8, 10,  8, 13,
#        14, 14,  8,  7, 14, 12,  6,  1,  1,  9, 10, 10,  3,  8,  1,  9,  6,
#         6,  5,  4,  6,  8,  9,  8,  3, 10,  2,  2,  9, 11, 15,  3,  5, 15,
#         4,  1, 14,  7,  7, 11,  5, 12, 13,  7,  2, 13,  4, 10, 12,  4, 13,
#         9, 15, 15, 14,  8, 10, 11, 15,  5,  5, 11, 11, 10,  9,  5,  4, 12,
#         6,  2,  8,  9,  6, 10,  4, 15,  6, 11,  7, 11, 12,  7, 14, 12,  4,
#         1,  1, 11, 12,  2, 11, 15, 10, 13,  2,  7,  3, 13,  3,  9,  6, 12,
#        15, 13, 12,  5, 14,  8,  1,  4,  3, 14,  9,  5,  1,  2, 15,  7])

# %%
len(ids)
# Out:
# 135

# %%
faces
# Out:
# [array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109,  95,  90, ..., 220, 230, 235],
#         [237, 215, 210, ..., 244, 236, 239],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [187, 179, 183, ..., 235, 216, 225],
#         [190, 183, 189, ..., 220, 200, 209],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[110, 114, 125, ..., 255, 255, 242],
#         [238, 241, 255, ..., 255, 255, 249],
#         [253, 255, 255, ..., 255, 252, 244],
#         ...,
#         [255, 255, 255, ..., 186, 182, 182],
#         [255, 255, 255, ..., 182, 178, 175],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 251, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[117, 129, 130, ..., 255, 255, 255],
#         [252, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  93,  89,  93],
#         [255, 255, 255, ..., 102,  97, 101],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 253, 239, 255],
#         [255, 255, 255, ..., 255, 239, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 115, 111, 116],
#         [255, 255, 255, ..., 119, 116, 119],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[114, 109, 111, ..., 255, 255, 255],
#         [249, 241, 244, ..., 255, 255, 255],
#         [255, 255, 246, ..., 255, 255, 255],
#         ...,
#         [204, 204, 204, ..., 250, 255, 255],
#         [202, 200, 199, ..., 252, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[108, 110, 123, ..., 255, 253, 239],
#         [234, 238, 255, ..., 255, 253, 245],
#         [251, 253, 255, ..., 255, 252, 242],
#         ...,
#         [255, 255, 255, ..., 178, 175, 176],
#         [255, 255, 255, ..., 176, 174, 171],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[ 78,  72,  79, ..., 255, 255, 248],
#         [171, 160, 176, ..., 255, 255, 249],
#         [165, 170, 180, ..., 250, 251, 255],
#         ...,
#         [ 79,  73,  67, ..., 196, 196, 206],
#         [ 76,  68,  65, ..., 192, 192, 201],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[ 85,  76,  72, ..., 232, 220, 218],
#         [186, 174, 164, ..., 232, 216, 217],
#         [151, 152, 154, ..., 223, 208, 224],
#         ...,
#         [ 68,  68,  66, ..., 174, 200, 236],
#         [ 72,  69,  66, ..., 172, 192, 230],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 200, 192, 195],
#         [255, 255, 255, ..., 217, 208, 217],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 252, 245, 255],
#         [255, 255, 255, ..., 255, 246, 255],
#         [255, 255, 255, ..., 231, 249, 255],
#         ...,
#         [255, 255, 255, ...,  37,  36,  38],
#         [255, 255, 255, ...,  37,  34,  37],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 250],
#         [255, 255, 255, ..., 255, 255, 249],
#         [255, 255, 255, ..., 255, 243, 235],
#         ...,
#         [255, 255, 255, ...,  60,  60,  61],
#         [255, 255, 255, ...,  59,  57,  60],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 248, 238],
#         [255, 255, 255, ..., 255, 242, 227],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 201, 195, 199],
#         [255, 255, 255, ..., 218, 211, 217],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[105, 103, 103, ..., 255, 255, 255],
#         [228, 221, 223, ..., 255, 255, 255],
#         [218, 203, 222, ..., 255, 255, 255],
#         ...,
#         [ 80,  81,  83, ..., 255, 255, 255],
#         [ 80,  82,  83, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 222, 211, 224],
#         [255, 255, 255, ..., 203, 207, 221],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 242, 243],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[114, 119, 124, ..., 255, 238, 244],
#         [251, 255, 255, ..., 255, 246, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [241, 255, 255, ..., 178, 165, 171],
#         [245, 255, 255, ..., 183, 164, 165],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[110,  96,  91, ..., 227, 225, 236],
#         [239, 217, 213, ..., 244, 237, 239],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [189, 181, 185, ..., 232, 215, 224],
#         [192, 186, 190, ..., 217, 199, 207],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[ 37,  38,  36, ..., 222, 196, 185],
#         [ 91,  94,  91, ..., 215, 194, 178],
#         [ 86,  87,  87, ..., 214, 203, 204],
#         ...,
#         [ 57,  62,  59, ..., 186, 163, 164],
#         [ 59,  64,  59, ..., 187, 152, 151],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 253, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 253, 250],
#         [255, 255, 255, ..., 255, 248, 248],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 235, 253, 255],
#         [255, 255, 255, ..., 229, 231, 249],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 231, 252, 251],
#         [255, 255, 255, ..., 223, 224, 245],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 249, 225, 217],
#         [255, 255, 255, ..., 255, 222, 206],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 252, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[110,  96,  91, ..., 224, 224, 236],
#         [239, 218, 211, ..., 244, 236, 239],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [199, 192, 195, ..., 227, 210, 221],
#         [204, 199, 202, ..., 228, 203, 202],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[111,  95,  90, ..., 225, 224, 234],
#         [237, 214, 208, ..., 244, 236, 239],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [187, 180, 183, ..., 234, 216, 224],
#         [190, 183, 188, ..., 220, 201, 209],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[117, 129, 130, ..., 255, 255, 255],
#         [249, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  93,  89,  90],
#         [255, 255, 255, ..., 100,  96, 101],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 251, 255, 255],
#         [255, 255, 255, ..., 225, 236, 244],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 229, 196, 199],
#         [255, 255, 255, ..., 227, 194, 197],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 246, 221, 213],
#         [255, 255, 255, ..., 248, 215, 201],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 230, 251, 248],
#         [255, 255, 255, ..., 221, 225, 243],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109, 111, 123, ..., 255, 255, 241],
#         [231, 237, 255, ..., 255, 255, 245],
#         [252, 255, 255, ..., 255, 252, 244],
#         ...,
#         [255, 255, 255, ..., 188, 183, 185],
#         [255, 255, 255, ..., 185, 181, 178],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109, 111, 124, ..., 255, 255, 241],
#         [235, 238, 255, ..., 255, 255, 245],
#         [252, 255, 255, ..., 255, 252, 244],
#         ...,
#         [255, 255, 255, ..., 186, 180, 180],
#         [255, 255, 255, ..., 181, 179, 175],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  41,  41,  46],
#         [255, 255, 255, ...,  41,  40,  44],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  65,  64,  65],
#         [248, 246, 245, ...,  55,  48,  48],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 235, 238, 255],
#         [255, 255, 255, ..., 234, 243, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[119, 129, 130, ..., 255, 255, 255],
#         [253, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  93,  89,  94],
#         [255, 255, 255, ..., 102,  98, 103],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 251, 252, 255],
#         [255, 255, 255, ..., 248, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 235, 246, 250],
#         [255, 255, 255, ..., 209, 216, 228],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 228, 225, 255],
#         [255, 255, 255, ..., 227, 229, 255],
#         [255, 255, 255, ..., 245, 235, 255],
#         ...,
#         [255, 255, 255, ..., 248, 229, 230],
#         [255, 255, 255, ..., 244, 228, 236],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  68,  67,  65],
#         [249, 248, 245, ...,  64,  54,  51],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [251, 252, 253, ..., 182, 174, 176],
#         [229, 231, 232, ..., 227, 220, 214],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 251, 255],
#         [255, 255, 255, ..., 255, 242, 255],
#         [255, 255, 255, ..., 255, 253, 255],
#         ...,
#         [255, 255, 255, ...,  51,  47,  48],
#         [255, 255, 255, ...,  51,  47,  48],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 201, 193, 196],
#         [255, 255, 255, ..., 217, 209, 218],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109, 112, 124, ..., 255, 255, 241],
#         [236, 239, 255, ..., 255, 255, 244],
#         [252, 255, 255, ..., 255, 251, 243],
#         ...,
#         [255, 255, 255, ..., 183, 181, 182],
#         [255, 255, 255, ..., 182, 178, 175],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 190, 182, 187],
#         [255, 255, 255, ..., 207, 200, 207],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 252, 255, 255],
#         [255, 255, 255, ..., 225, 236, 244],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 243, 255, 255],
#         [255, 255, 255, ..., 237, 241, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[111, 116, 121, ..., 244, 227, 236],
#         [248, 255, 255, ..., 250, 242, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [231, 251, 255, ..., 173, 160, 166],
#         [238, 253, 250, ..., 179, 160, 161],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 253, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 237, 231, 237],
#         [255, 255, 255, ..., 241, 236, 244],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 242, 239],
#         [255, 255, 255, ..., 255, 237, 239],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[124, 116, 102, ..., 255, 242, 246],
#         [255, 251, 230, ..., 255, 246, 248],
#         [246, 227, 231, ..., 255, 255, 255],
#         ...,
#         [243, 245, 255, ..., 231, 220, 216],
#         [255, 255, 255, ..., 213, 206, 218],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 248, 250, 255],
#         [255, 255, 255, ..., 245, 252, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 241, 242],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 249, 224, 217],
#         [255, 255, 255, ..., 253, 221, 206],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 245, 255, 255],
#         [255, 255, 255, ..., 239, 242, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 129, 121, ..., 190, 182, 185],
#         [255, 255, 255, ..., 183, 183, 192],
#         [255, 255, 255, ..., 175, 185, 209],
#         ...,
#         [161, 164, 161, ...,  47,  48,  50],
#         [163, 164, 161, ...,  50,  44,  43],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 218, 214, 237],
#         [255, 255, 255, ..., 214, 215, 253],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  25,  24,  25],
#         [253, 255, 255, ...,  26,  25,  26],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[119, 129, 130, ..., 255, 255, 255],
#         [253, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  91,  88,  91],
#         [255, 255, 255, ..., 101,  98, 102],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 146, 132, 147],
#         [248, 245, 244, ..., 142, 129, 140],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[105, 103, 109, ..., 255, 255, 255],
#         [230, 228, 237, ..., 255, 255, 255],
#         [224, 227, 238, ..., 255, 255, 255],
#         ...,
#         [ 68,  69,  69, ..., 126, 114, 103],
#         [ 65,  66,  66, ..., 126, 114, 103],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 244, 255, 255],
#         [255, 255, 255, ..., 238, 242, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 239, 238],
#         [255, 255, 255, ..., 255, 234, 238],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[119, 129, 130, ..., 255, 255, 255],
#         [251, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  93,  89,  93],
#         [255, 255, 255, ..., 102,  98, 102],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 251, 255, 255],
#         [255, 255, 255, ..., 225, 236, 244],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[114, 121, 124, ..., 255, 238, 245],
#         [255, 255, 255, ..., 255, 250, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [250, 255, 255, ..., 176, 163, 171],
#         [250, 255, 255, ..., 185, 164, 165],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[112,  97,  93, ..., 227, 225, 235],
#         [241, 218, 211, ..., 246, 237, 242],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [196, 188, 192, ..., 232, 213, 223],
#         [200, 193, 199, ..., 216, 197, 207],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109, 111, 124, ..., 255, 255, 243],
#         [235, 239, 255, ..., 255, 253, 244],
#         [253, 255, 255, ..., 253, 251, 243],
#         ...,
#         [255, 255, 255, ..., 187, 183, 183],
#         [255, 255, 255, ..., 183, 180, 179],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 245, 237],
#         [255, 255, 255, ..., 255, 238, 235],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 239, 238],
#         [255, 255, 255, ..., 255, 234, 238],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[110,  96,  91, ..., 224, 224, 236],
#         [239, 218, 211, ..., 244, 236, 239],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [199, 192, 195, ..., 227, 210, 221],
#         [204, 199, 202, ..., 228, 203, 202],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[122, 118, 118, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 251, ..., 255, 255, 255],
#         ...,
#         [100, 108, 114, ..., 255, 255, 255],
#         [104, 112, 114, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 238, 250, 251],
#         [255, 255, 255, ..., 211, 222, 230],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[108, 116, 117, ..., 156, 147, 167],
#         [237, 248, 244, ..., 163, 152, 171],
#         [236, 243, 228, ..., 158, 157, 175],
#         ...,
#         [231, 223, 222, ..., 130, 123, 123],
#         [241, 227, 230, ..., 124, 114, 122],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[122, 112, 109, ..., 255, 255, 255],
#         [255, 246, 241, ..., 255, 255, 255],
#         [252, 244, 252, ..., 255, 255, 255],
#         ...,
#         [ 78,  79,  76, ..., 255, 255, 255],
#         [ 79,  79,  76, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  58,  55,  57],
#         [250, 249, 246, ...,  71,  51,  47],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [179, 180, 181, ..., 114, 100,  96],
#         [165, 165, 166, ..., 102,  89,  78],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 241, 241],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[112, 118, 123, ..., 251, 232, 242],
#         [252, 255, 255, ..., 253, 244, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [242, 255, 255, ..., 167, 156, 160],
#         [245, 255, 255, ..., 186, 168, 159],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 249, 255, 255],
#         [255, 255, 255, ..., 222, 231, 243],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 216, 224, 244],
#         [255, 255, 255, ..., 215, 220, 245],
#         [255, 255, 255, ..., 231, 211, 231],
#         ...,
#         [255, 255, 255, ..., 192, 197, 203],
#         [255, 255, 255, ..., 189, 207, 215],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 174, 152, 132],
#         [245, 244, 243, ..., 171, 164, 145],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[115, 122, 126, ..., 255, 236, 245],
#         [255, 255, 255, ..., 255, 251, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 163, 151, 157],
#         [255, 255, 255, ..., 168, 151, 151],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[ 75,  72,  72, ..., 255, 255, 255],
#         [170, 161, 164, ..., 255, 255, 255],
#         [163, 158, 159, ..., 255, 255, 255],
#         ...,
#         [145, 151, 153, ..., 255, 255, 253],
#         [146, 153, 159, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 129, 100,  79],
#         [248, 246, 245, ..., 128, 101,  73],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 248, 250, 255],
#         [255, 255, 255, ..., 246, 253, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 243, 255, 255],
#         [255, 255, 255, ..., 238, 241, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[ 97, 107, 119, ..., 255, 255, 255],
#         [221, 239, 255, ..., 255, 255, 255],
#         [221, 255, 255, ..., 255, 255, 255],
#         ...,
#         [110, 112, 111, ..., 158, 154, 159],
#         [111, 110, 111, ..., 163, 158, 165],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109, 111, 124, ..., 255, 253, 239],
#         [234, 237, 255, ..., 255, 255, 245],
#         [251, 255, 255, ..., 255, 251, 241],
#         ...,
#         [255, 255, 255, ..., 179, 173, 174],
#         [255, 255, 255, ..., 176, 173, 171],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 195, 187, 190],
#         [255, 255, 255, ..., 211, 204, 210],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 244, 242],
#         [255, 255, 255, ..., 255, 241, 243],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109,  95,  89, ..., 224, 224, 232],
#         [237, 213, 207, ..., 242, 235, 236],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [188, 179, 183, ..., 229, 213, 223],
#         [192, 182, 188, ..., 214, 194, 204],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[110, 117, 121, ..., 251, 231, 241],
#         [250, 255, 255, ..., 249, 243, 252],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [243, 255, 255, ..., 167, 156, 160],
#         [246, 255, 255, ..., 171, 153, 154],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 203, 195, 199],
#         [255, 255, 255, ..., 218, 210, 218],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 128, 108, ..., 253, 244, 255],
#         [255, 255, 220, ..., 249, 243, 255],
#         [246, 223, 232, ..., 252, 241, 255],
#         ...,
#         [249, 246, 255, ..., 160, 161, 163],
#         [255, 252, 255, ..., 154, 159, 163],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[118, 129, 130, ..., 255, 255, 255],
#         [253, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ...,  91,  88,  91],
#         [255, 255, 255, ..., 101,  97, 102],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 243, 244],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 237, 229],
#         [255, 255, 255, ..., 255, 230, 215],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 239, 249, 253],
#         [255, 255, 255, ..., 214, 221, 235],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 243, 245],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 246, 243],
#         [255, 255, 255, ..., 255, 239, 241],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[ 55,  68,  75, ..., 196, 181, 210],
#         [130, 156, 170, ..., 183, 188, 210],
#         [130, 131, 146, ..., 203, 195, 200],
#         ...,
#         [ 33,  33,  33, ..., 112, 109, 111],
#         [ 34,  34,  34, ..., 118, 115, 118],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 244, 255, 255],
#         [255, 255, 255, ..., 255, 253, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[109, 111, 124, ..., 255, 253, 239],
#         [234, 237, 255, ..., 255, 255, 245],
#         [251, 255, 255, ..., 255, 251, 241],
#         ...,
#         [255, 255, 255, ..., 179, 173, 174],
#         [255, 255, 255, ..., 176, 173, 171],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8),
#  array([[130, 130, 130, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         ...,
#         [255, 255, 255, ..., 255, 255, 255],
#         [255, 255, 255, ..., 255, 255, 255],
#         [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8)]

# %%
faces[0].shape #tamanhos da imagem
# Out:
# (243, 320)

# %% [markdown]
# ## Treinando o classificador LBPH

# %%
'''dentro do arquivo tem os parametros usados
padrão: precisão = 0,66666...
radius = 2, nei = 5, x, y = 5: precisão 0,6
radius = 3, nei = 12, x, y = 5: precisão 0,6
radius = 4, nei = 14, x, y = 9: precisão 0,7
'''
lbph = cv2.face.LBPHFaceRecognizer_create(radius = 4, neighbors = 14, grid_x=9, grid_y=9)
lbph.train(faces, ids)
lbph.write('classificador_lbph.yml')

# %% [markdown]
# ## Reconhecimento de faces

# %%
classificador_face = cv2.face.LBPHFaceRecognizer_create()
classificador_face.read('/content/classificador_lbph.yml')

# %%
imagem_teste = '/content/yalefaces/test/subject01.happy.gif'

# %%
imagem = Image.open(imagem_teste).convert('L')
imagem_np = np.array(imagem, 'uint8')
imagem_np
# Out:
# array([[130, 130, 130, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 249, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [ 68,  68,  68, ...,  68,  68,  68]], dtype=uint8)

# %%
previsao = classificador_face.predict(imagem_np)
previsao
# Out:
# (1, 63.26476332390736)

# %% [markdown]
# ## Avaliação do classificador

# %%
saida_esperada = int(os.path.split(imagem_teste)[1].split('.')[0].replace('subject', ''))

# %%
cv2.putText(imagem_np, 'Pred: ' + str(previsao[0]), (10,30), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0))
cv2.putText(imagem_np, 'Exp: ' + str(saida_esperada), (10,50), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0))
cv2_imshow(imagem_np)
# Out:
# <PIL.Image.Image image mode=L size=320x243>

# %%
caminhos = [os.path.join('/content/yalefaces/test', f) for f in os.listdir('/content/yalefaces/test')]
previsoes = []
saidas_esperadas = []
for caminho in caminhos:
  imagem = Image.open(caminho).convert('L') #deixando no formato da biblioteca PIL
  imagem_np = np.array(imagem, 'uint8')
  previsao, _ = classificador_face.predict(imagem_np)
  saida_esperada = int(os.path.split(caminho)[1].split('.')[0].replace('subject', '')) #pegando o numero da pessoa
  previsoes.append(previsao)
  saidas_esperadas.append(saida_esperada)

# %%
type(previsoes), type(saidas_esperadas)
# Out:
# (list, list)

# %%
previsoes = np.array(previsoes)
saidas_esperadas = np.array(saidas_esperadas)

# %%
previsoes
# Out:
# array([ 3,  4,  8,  4,  9,  1, 15,  9,  4,  4,  4, 11, 14, 12,  4,  5,  7,
#        13, 13, 14,  7,  3, 12, 14, 11,  6, 10,  5, 12,  7])

# %%
saidas_esperadas
# Out:
# array([ 3,  4,  8,  4,  7,  1, 15,  9,  2,  1, 10, 11, 14, 12,  8,  5, 15,
#        13, 13, 14,  7,  3,  2,  6, 11,  6, 10,  5, 12,  9])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(saidas_esperadas, previsoes)
# Out:
# 0.7

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(saidas_esperadas, previsoes)
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Dlib

# %%
import dlib

# %% [markdown]
# ## Detecção de pontos faciais

# %%
detector_face = dlib.get_frontal_face_detector()
detector_pontos_faciais = dlib.shape_predictor('/content/drive/MyDrive/estudo de visao computacional/Weights/shape_predictor_68_face_landmarks.dat')

# %%
imagem = cv2.imread('/content/drive/MyDrive/estudo de visao computacional/Images/people2.jpg')
deteccoes = detector_face(imagem, 1)
for face in deteccoes:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(imagem,(l,t), (r,b), (0,0,0), 2)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1023x537>

# %%
imagem = cv2.imread('/content/drive/MyDrive/estudo de visao computacional/Images/people2.jpg')
deteccoes = detector_face(imagem, 1)
for face in deteccoes:
  pontos = detector_pontos_faciais(imagem, face)
  #print(len(pontos.parts())) cada face são extraidos 68 pontos
  for ponto in pontos.parts():
    cv2.circle(imagem, (ponto.x, ponto.y), 2, (0,0,255))

  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(imagem,(l,t), (r,b), (0,0,0), 2)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=1023x537>

# %% [markdown]
# ## Detecção dos descritores faciais

# %%
#é importado uma CNN para detectar o rosto
#resnet: https://arvix.org/abs/1512.03385
descritor_facial = dlib.face_recognition_model_v1('/content/drive/MyDrive/estudo de visao computacional/Weights/dlib_face_recognition_resnet_model_v1.dat')

# %%
index = {}
idx = 0
descricoes = None

caminhos = [os.path.join('/content/yalefaces/train', f) for f in os.listdir('/content/yalefaces/train')]
for caminho in caminhos:
  imagem = Image.open(caminho).convert('RGB')
  imagem_np = np.array(imagem, 'uint8')
  deteccoes = detector_face(imagem_np, 1)
  for face in deteccoes:
    l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
    cv2.rectangle(imagem_np,(l,t), (r,b), (0,0,0), 2)

    pontos = detector_pontos_faciais(imagem_np, face)
    for ponto in pontos.parts():
      cv2.circle(imagem_np, (ponto.x, ponto.y), 2, (0,0,255))

    descritores_faciais = descritor_facial.compute_face_descriptor(imagem_np, pontos) #ele vem em vetor do dlib com 128 valores
    descritores_faciais = [f for f in descritores_faciais] #transformando em lista
    descritores_faciais = np.array(descritores_faciais, dtype=np.float64) #transformando em array
    descritores_faciais = descritores_faciais[np.newaxis, :]

    if descricoes is None:
      descricoes = descritores_faciais
    else:
      descricoes= np.concatenate((descricoes, descritores_faciais), axis=0)
    index[idx] = caminho
    idx+=1

# %%
descricoes.shape
# Out:
# (132, 128)

# %%
index
# Out:
# {0: '/content/yalefaces/train/subject03.sleepy.gif',
#  1: '/content/yalefaces/train/subject14.happy.gif',
#  2: '/content/yalefaces/train/subject06.glasses.gif',
#  3: '/content/yalefaces/train/subject02.wink.gif',
#  4: '/content/yalefaces/train/subject01.sleepy.gif',
#  5: '/content/yalefaces/train/subject05.happy.gif',
#  6: '/content/yalefaces/train/subject13.leftlight.gif',
#  7: '/content/yalefaces/train/subject07.rightlight.gif',
#  8: '/content/yalefaces/train/subject03.sad.gif',
#  9: '/content/yalefaces/train/subject02.sleepy.gif',
#  10: '/content/yalefaces/train/subject03.rightlight.gif',
#  11: '/content/yalefaces/train/subject04.rightlight.gif',
#  12: '/content/yalefaces/train/subject13.happy.gif',
#  13: '/content/yalefaces/train/subject08.leftlight.gif',
#  14: '/content/yalefaces/train/subject10.leftlight.gif',
#  15: '/content/yalefaces/train/subject08.sleepy.gif',
#  16: '/content/yalefaces/train/subject13.glasses.gif',
#  17: '/content/yalefaces/train/subject14.rightlight.gif',
#  18: '/content/yalefaces/train/subject14.centerlight.gif',
#  19: '/content/yalefaces/train/subject08.surprised.gif',
#  20: '/content/yalefaces/train/subject07.surprised.gif',
#  21: '/content/yalefaces/train/subject14.glasses.gif',
#  22: '/content/yalefaces/train/subject12.sad.gif',
#  23: '/content/yalefaces/train/subject06.sleepy.gif',
#  24: '/content/yalefaces/train/subject01.surprised.gif',
#  25: '/content/yalefaces/train/subject09.wink.gif',
#  26: '/content/yalefaces/train/subject10.noglasses.gif',
#  27: '/content/yalefaces/train/subject10.surprised.gif',
#  28: '/content/yalefaces/train/subject03.happy.gif',
#  29: '/content/yalefaces/train/subject08.noglasses.gif',
#  30: '/content/yalefaces/train/subject01.glasses.gif',
#  31: '/content/yalefaces/train/subject09.centerlight.gif',
#  32: '/content/yalefaces/train/subject06.noglasses.gif',
#  33: '/content/yalefaces/train/subject06.surprised.gif',
#  34: '/content/yalefaces/train/subject05.wink.gif',
#  35: '/content/yalefaces/train/subject04.normal.gif',
#  36: '/content/yalefaces/train/subject06.centerlight.gif',
#  37: '/content/yalefaces/train/subject08.centerlight.gif',
#  38: '/content/yalefaces/train/subject09.glasses.gif',
#  39: '/content/yalefaces/train/subject08.wink.gif',
#  40: '/content/yalefaces/train/subject03.surprised.gif',
#  41: '/content/yalefaces/train/subject10.glasses.gif',
#  42: '/content/yalefaces/train/subject02.glasses.gif',
#  43: '/content/yalefaces/train/subject02.sad.gif',
#  44: '/content/yalefaces/train/subject09.leftlight.gif',
#  45: '/content/yalefaces/train/subject11.wink.gif',
#  46: '/content/yalefaces/train/subject15.surprised.gif',
#  47: '/content/yalefaces/train/subject03.wink.gif',
#  48: '/content/yalefaces/train/subject05.normal.gif',
#  49: '/content/yalefaces/train/subject15.sleepy.gif',
#  50: '/content/yalefaces/train/subject04.noglasses.gif',
#  51: '/content/yalefaces/train/subject01.noglasses.gif',
#  52: '/content/yalefaces/train/subject14.leftlight.gif',
#  53: '/content/yalefaces/train/subject07.glasses.gif',
#  54: '/content/yalefaces/train/subject07.sad.gif',
#  55: '/content/yalefaces/train/subject11.sleepy.gif',
#  56: '/content/yalefaces/train/subject05.centerlight.gif',
#  57: '/content/yalefaces/train/subject12.leftlight.gif',
#  58: '/content/yalefaces/train/subject13.surprised.gif',
#  59: '/content/yalefaces/train/subject07.centerlight.gif',
#  60: '/content/yalefaces/train/subject02.surprised.gif',
#  61: '/content/yalefaces/train/subject13.normal.gif',
#  62: '/content/yalefaces/train/subject04.happy.gif',
#  63: '/content/yalefaces/train/subject10.wink.gif',
#  64: '/content/yalefaces/train/subject12.sleepy.gif',
#  65: '/content/yalefaces/train/subject04.centerlight.gif',
#  66: '/content/yalefaces/train/subject13.centerlight.gif',
#  67: '/content/yalefaces/train/subject09.happy.gif',
#  68: '/content/yalefaces/train/subject15.centerlight.gif',
#  69: '/content/yalefaces/train/subject15.glasses.gif',
#  70: '/content/yalefaces/train/subject14.sleepy.gif',
#  71: '/content/yalefaces/train/subject08.sad.gif',
#  72: '/content/yalefaces/train/subject10.sleepy.gif',
#  73: '/content/yalefaces/train/subject11.leftlight.gif',
#  74: '/content/yalefaces/train/subject15.happy.gif',
#  75: '/content/yalefaces/train/subject05.leftlight.gif',
#  76: '/content/yalefaces/train/subject05.glasses.gif',
#  77: '/content/yalefaces/train/subject11.sad.gif',
#  78: '/content/yalefaces/train/subject10.normal.gif',
#  79: '/content/yalefaces/train/subject09.normal.gif',
#  80: '/content/yalefaces/train/subject05.sad.gif',
#  81: '/content/yalefaces/train/subject04.sad.gif',
#  82: '/content/yalefaces/train/subject12.happy.gif',
#  83: '/content/yalefaces/train/subject06.sad.gif',
#  84: '/content/yalefaces/train/subject02.happy.gif',
#  85: '/content/yalefaces/train/subject08.glasses.gif',
#  86: '/content/yalefaces/train/subject09.noglasses.gif',
#  87: '/content/yalefaces/train/subject06.normal.gif',
#  88: '/content/yalefaces/train/subject10.rightlight.gif',
#  89: '/content/yalefaces/train/subject04.wink.gif',
#  90: '/content/yalefaces/train/subject15.leftlight.gif',
#  91: '/content/yalefaces/train/subject06.rightlight.gif',
#  92: '/content/yalefaces/train/subject11.surprised.gif',
#  93: '/content/yalefaces/train/subject07.wink.gif',
#  94: '/content/yalefaces/train/subject11.centerlight.gif',
#  95: '/content/yalefaces/train/subject12.centerlight.gif',
#  96: '/content/yalefaces/train/subject07.normal.gif',
#  97: '/content/yalefaces/train/subject14.wink.gif',
#  98: '/content/yalefaces/train/subject12.wink.gif',
#  99: '/content/yalefaces/train/subject04.glasses.gif',
#  100: '/content/yalefaces/train/subject01.leftlight.gif',
#  101: '/content/yalefaces/train/subject01.sad.gif',
#  102: '/content/yalefaces/train/subject11.normal.gif',
#  103: '/content/yalefaces/train/subject12.glasses.gif',
#  104: '/content/yalefaces/train/subject02.rightlight.gif',
#  105: '/content/yalefaces/train/subject11.noglasses.gif',
#  106: '/content/yalefaces/train/subject15.noglasses.gif',
#  107: '/content/yalefaces/train/subject10.happy.gif',
#  108: '/content/yalefaces/train/subject13.rightlight.gif',
#  109: '/content/yalefaces/train/subject02.normal.gif',
#  110: '/content/yalefaces/train/subject07.sleepy.gif',
#  111: '/content/yalefaces/train/subject03.normal.gif',
#  112: '/content/yalefaces/train/subject13.wink.gif',
#  113: '/content/yalefaces/train/subject03.noglasses.gif',
#  114: '/content/yalefaces/train/subject09.sleepy.gif',
#  115: '/content/yalefaces/train/subject06.wink.gif',
#  116: '/content/yalefaces/train/subject12.surprised.gif',
#  117: '/content/yalefaces/train/subject15.normal.gif',
#  118: '/content/yalefaces/train/subject13.noglasses.gif',
#  119: '/content/yalefaces/train/subject12.noglasses.gif',
#  120: '/content/yalefaces/train/subject05.noglasses.gif',
#  121: '/content/yalefaces/train/subject14.surprised.gif',
#  122: '/content/yalefaces/train/subject08.happy.gif',
#  123: '/content/yalefaces/train/subject01.normal.gif',
#  124: '/content/yalefaces/train/subject04.sleepy.gif',
#  125: '/content/yalefaces/train/subject03.centerlight.gif',
#  126: '/content/yalefaces/train/subject14.noglasses.gif',
#  127: '/content/yalefaces/train/subject09.surprised.gif',
#  128: '/content/yalefaces/train/subject01.wink.gif',
#  129: '/content/yalefaces/train/subject02.noglasses.gif',
#  130: '/content/yalefaces/train/subject15.wink.gif',
#  131: '/content/yalefaces/train/subject07.noglasses.gif'}

# %%
len(index)
# Out:
# 132

# %% [markdown]
# ## Calculo da distancia entre os descritores faciais das pessoas
# - é por meio desse calculo que conseguimos identificar o rosto da pessoa

# %%
#identificando semelhanças entre descritores faciais
np.linalg.norm(descricoes[131] - descricoes[131])
#aqui percebemos que, quanto menor o valor, mais parecido as faces são
# Out:
# 0.0

# %%
np.linalg.norm(descricoes[131] - descricoes[130])
# Out:
# 0.6404640902479888

# %%
#agora vamos comparar uma unica face com todas as outras que temos
np.linalg.norm(descricoes[0] - descricoes, axis = 1)
# Out:
# array([0.        , 0.67497253, 0.67357083, 0.68082633, 0.61888044,
#        0.69629137, 0.64680409, 0.85054926, 0.40884808, 0.67670903,
#        0.40650144, 0.72571971, 0.56156784, 0.49420488, 0.77846121,
#        0.52870288, 0.57593873, 0.73802569, 0.68778211, 0.53345266,
#        0.77622097, 0.63322677, 0.66521951, 0.66581105, 0.71759155,
#        0.55973166, 0.67461699, 0.73057372, 0.28035181, 0.54807521,
#        0.6918859 , 0.61335403, 0.67355336, 0.67647903, 0.66710998,
#        0.66488025, 0.67194743, 0.55235021, 0.58914512, 0.52245242,
#        0.47761013, 0.65358009, 0.74833982, 0.69825369, 0.67765326,
#        0.68026378, 0.57751082, 0.3411156 , 0.63976862, 0.51822959,
#        0.67258492, 0.62344463, 0.74473518, 0.73455512, 0.72653527,
#        0.7228986 , 0.65841159, 0.67506229, 0.55918277, 0.81968805,
#        0.73169519, 0.56609765, 0.6738295 , 0.68705495, 0.67843278,
#        0.71447386, 0.64026524, 0.57342546, 0.56037269, 0.5981395 ,
#        0.62061803, 0.53824407, 0.67321435, 0.86684631, 0.52262602,
#        0.67145894, 0.68258054, 0.68217012, 0.67404511, 0.6105359 ,
#        0.61683723, 0.66488025, 0.64800097, 0.67360575, 0.74325258,
#        0.52319733, 0.6105359 , 0.67355336, 0.71273245, 0.59054442,
#        0.5542724 , 0.73464373, 0.7222124 , 0.69486794, 0.7522816 ,
#        0.67558188, 0.74141694, 0.66427161, 0.71344324, 0.74425704,
#        0.64643689, 0.62924341, 0.72405733, 0.75450871, 0.77172531,
#        0.73664313, 0.56227728, 0.69973434, 0.58016458, 0.71609518,
#        0.76355171, 0.28389932, 0.56005518, 0.28389932, 0.52857725,
#        0.7236142 , 0.67795051, 0.5578196 , 0.53791248, 0.69199604,
#        0.63817391, 0.68057828, 0.52215724, 0.63665364, 0.70696554,
#        0.39107178, 0.64202628, 0.57663732, 0.64855613, 0.71609518,
#        0.61108474, 0.74141694])

# %%
#vendo qual o menor valor possivel de uma face, sem ser ela mesma
np.argmin(np.linalg.norm(descricoes[0] - descricoes[1:], axis = 1))
# Out:
# 27

# %%
np.linalg.norm(descricoes[0] - descricoes[1:], axis = 1)[27]
# Out:
# 0.28035180689510186

# %% [markdown]
# ## Detecção de faces

# %%
confianca = 0.5
caminhos = [os.path.join('/content/yalefaces/test', f) for f in os.listdir('/content/yalefaces/test')]
for caminho in caminhos:
  imagem = Image.open(caminho).convert('RGB')
  imagem_np = np.array(imagem, 'uint8')
  deteccoes = detector_face(imagem_np, 1)
  for face in deteccoes:
    pontos = detector_pontos_faciais(imagem_np, face)
    descritores_faciais = descritor_facial.compute_face_descriptor(imagem_np, pontos)
    descritores_faciais = [f for f in descritores_faciais] #transformando em lista
    descritores_faciais = np.array(descritores_faciais, dtype=np.float64) #transformando em array
    descritores_faciais = descritores_faciais[np.newaxis, :]

    distancias = np.linalg.norm(descritores_faciais - descricoes, axis=1)
    indice_minimo = np.argmin(distancias)
    distancia_minima = distancias[indice_minimo]
    if distancia_minima <= confianca:
      saida_previsao = int(os.path.split(index[indice_minimo])[1].split('.')[0].replace('subject', ''))
    else:
      saida_previsao = 'face não identificada'

    saida_esperada = int(os.path.split(caminho)[1].split('.')[0].replace('subject', ''))

    cv2.putText(imagem_np, 'Pred: ' + str(saida_previsao), (10,30), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
    cv2.putText(imagem_np, 'Pred: ' + str(saida_esperada), (10,50), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0,0,0))
  cv2_imshow(imagem_np)
# Out:
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>
# <PIL.Image.Image image mode=RGB size=320x243>

# %% [markdown]
# # Atividade
